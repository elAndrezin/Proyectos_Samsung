# %%
import pandas as pd

# %%
Dataframe_colegio = pd.read_csv('C:/Users/andre/Documents/Curso Samsung/Proyecto/student-mat.csv', delimiter= ';')

# %%
Dataframe_colegio.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
Dataframe_colegio = Dataframe_colegio.drop(['famsize',  'Medu',  'Fedu',  'Fjob', 'reason',  'schoolsup',  'famsup',  'activities',  'nursery',  'higher', 'romantic',  'famrel',  
'freetime',  'goout',  'Dalc', 'Walc'], axis=1)

# %%
GP_math = Dataframe_colegio[Dataframe_colegio['school']=='GP']

# %%
GP_math.head(349)
# Out:
#     school sex  age address Pstatus     Mjob guardian  traveltime  studytime  \
# 0       GP   F   18       U       A  at_home   mother           2          2
# 1       GP   F   17       U       T  at_home   father           1          2
# 2       GP   F   15       U       T  at_home   mother           1          2
# 3       GP   F   15       U       T   health   mother           1          3
# 4       GP   F   16       U       T    other   father           1          2
# ..     ...  ..  ...     ...     ...      ...      ...         ...        ...
# 344     GP   F   18       U       T  at_home   mother           1          3
# 345     GP   F   18       U       T    other   mother           1          3
# 346     GP   M   18       R       T  teacher   mother           1          3
# 347     GP   M   18       U       T  teacher   mother           1          3
# 348     GP   F   17       U       T   health   mother           1          3
#
# ...

# %%
len(GP_math)
# Out:
# 349

# %%
MS_math=Dataframe_colegio[Dataframe_colegio['school']=='MS']

# %%
MS_math.head(46)
# Out:
#     school sex  age address Pstatus      Mjob guardian  traveltime  studytime  \
# 349     MS   M   18       R       T     other   mother           2          1
# 350     MS   M   19       R       T     other    other           3          2
# 351     MS   M   17       U       T    health   mother           2          2
# 352     MS   M   18       U       T   at_home   mother           1          1
# 353     MS   M   19       R       T     other    other           3          1
# 354     MS   M   17       R       T  services   mother           2          2
# 355     MS   F   18       U       T  services   father           1          2
# 356     MS   F   17       R       T   teacher   father           2          2
# 357     MS   F   17       U       A  services   mother           2          2
# 358     MS   M   18       U       T     other   father           2          1
# 359     MS   F   18       U       T   at_home   father           2          3
# ...

# %%
len(MS_math)
# Out:
# 46

# %%
GP_math.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# Pstatus       0
# Mjob          0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# paid          0
# internet      0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
MS_math.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# Pstatus       0
# Mjob          0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# paid          0
# internet      0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
GP_math.value_counts('sex')
# Out:
# sex
# F    183
# M    166
# dtype: int64

# %%
GP_math.value_counts('sex').plot(kind="pie", autopct=("%1.1f%%"), explode = [0.1, 0])
plt.ylabel('SEX')
# Out:
# Text(0, 0.5, 'SEX')

# %%
MS_math.value_counts('sex').plot(kind="pie", autopct=("%1.1f%%"), explode = [0.1, 0])
plt.ylabel('SEX')
# Out:
# Text(0, 0.5, 'SEX')

# %%
plt.figure(figsize=(10,5))
GP_math.value_counts('age').plot(kind="bar", color = 'firebrick')
plt.title('Edad de los estudianes - Colegio GP')
# Out:
# Text(0.5, 1.0, 'Edad de los estudianes - Colegio GP')

# %%
plt.figure(figsize=(10,5))
MS_math.value_counts('age').plot(kind="bar", color = 'gray')
plt.title('Edad de los estudianes - Colegio MS')
# Out:
# Text(0.5, 1.0, 'Edad de los estudianes - Colegio MS')

# %%
GP_math['age'].mean()
# Out:
# 16.521489971346703

# %%
MS_math['age'].mean()
# Out:
# 18.02173913043478

# %%
GP_math_promedio=GP_math[['G1', 'G2','G3']].mean()
print(GP_math_promedio)
# Out:
# G1    10.939828
# G2    10.782235
# G3    10.489971
# dtype: float64

# %%
MS_math_promedio=MS_math[['G1','G2','G3']].mean()
print(MS_math_promedio)
# Out:
# G1    10.673913
# G2    10.195652
# G3     9.847826
# dtype: float64

# %%
grupos_GP = ['G1','G2','G3']
#GP_math[['G1','G2','G3']].mean().plot(kind = "bar")
plt.barh(grupos_GP,GP_math_promedio, color='firebrick')
plt.title('Grafica promedio notas - Colegio GP')
plt.ylabel('GRUPOS')
plt.xlabel('CALIFICACIONES')
# Out:
# Text(0.5, 0, 'CALIFICACIONES')

# %%
grupos_MS = ['G1','G2','G3']
plt.barh(grupos_MS ,MS_math_promedio, color='grey')
plt.title('Grafica promedio notas - Colegio MS')
plt.ylabel('GRUPOS')
plt.xlabel('CALIFICACIONES')
# Out:
# Text(0.5, 0, 'CALIFICACIONES')

# %%
ClasesMAX_GP = GP_math['absences'].max()
print(ClasesMAX_GP)

ClasesMAX_MS = MS_math['absences'].max()
print(ClasesMAX_MS)
# Out:
# 75
# 17

# %%
#AsistenciaGP = ((ClasesMAX_GP-GP_math['absences'])/ClasesMAX_GP)*100


AsistMS = ((ClasesMAX_MS - MS_math['absences'])/ClasesMAX_MS) * 100

AsistGP = ((ClasesMAX_GP - GP_math['absences'])/ClasesMAX_GP) * 100

AsistT_Math = AsistGP.add(AsistMS, fill_value = 0)
G3T_Math = GP_math['G3'].add(MS_math['G3'], fill_value = 0)

print(AsistT_Math)

As1 = AsistT_Math.lt(80) 
G3a = G3T_Math.lt(10)
G3b = G3T_Math.lt(15)
i = 0
app = []
ex   = []

while(i < 395): 
    if(As1[i] == True):
        app.append(0)
        ex.append(0)
        i+=1
    elif(As1[i] == False) & (G3a[i] == True):
        app.append(0)
        ex.append(0)
        i+=1
    elif (As1[i] == False) & (G3a[i] == False) & (G3b[i] == True):
        app.append(1)
        ex.append(1)
        i+=1
    elif (As1[i] == False) & (G3b[i] == False):
        app.append(1)
        ex.append(0)
        i+=1 

Dataframe_colegio = Dataframe_colegio.assign(APPROVED = app, EXTRA = ex)
# Out:
# 0       92.000000
# 1       94.666667
# 2       86.666667
# 3       97.333333
# 4       94.666667
#           ...
# 390     35.294118
# 391     82.352941
# 392     82.352941
# 393    100.000000
# 394     70.588235
# Name: absences, Length: 395, dtype: float64

# %%
Dataframe_colegio.head()
# Out:
#   school sex  age address Pstatus     Mjob guardian  traveltime  studytime  \
# 0     GP   F   18       U       A  at_home   mother           2          2
# 1     GP   F   17       U       T  at_home   father           1          2
# 2     GP   F   15       U       T  at_home   mother           1          2
# 3     GP   F   15       U       T   health   mother           1          3
# 4     GP   F   16       U       T    other   father           1          2
#
#    failures paid internet  health  absences  G1  G2  G3  APPROVED  EXTRA
# 0         0   no       no       3         6   5   6   6         0      0
# 1         0   no      yes       3         4   5   5   6         0      0
# 2         3  yes      yes       3        10   7   8  10         1      1
# 3         0  yes      yes       5         2  15  14  15         1      0
# 4         0  yes       no       5         4   6  10  10         1      1

# %%
#----------------------------------------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------------------------------------
#------------------------------------------- DATSFRAME CURSO PORTUGUES ------------------------------------------------
#----------------------------------------------------------------------------------------------------------------------
#----------------------------------------------------------------------------------------------------------------------

# %%
Dataframe_colegio1 = pd.read_csv('C:/Users/andre/Documents/Curso Samsung/Proyecto/student-por.csv', delimiter=';')

# %%
Dataframe_colegio1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
len(Dataframe_colegio1)
# Out:
# 649

# %%
Dataframe_colegio1 = Dataframe_colegio1.drop(['famsize',  'Medu',  'Fedu',  'Fjob', 'reason',  'schoolsup',  'famsup',  'activities',  'nursery',  'higher', 'romantic',  'famrel',  
'freetime',  'goout',  'Dalc', 'Walc'], axis=1)

# %%
GP_port = Dataframe_colegio1[Dataframe_colegio1['school']=='GP'] 
GP_port.head()
# Out:
#   school sex  age address Pstatus     Mjob guardian  traveltime  studytime  \
# 0     GP   F   18       U       A  at_home   mother           2          2
# 1     GP   F   17       U       T  at_home   father           1          2
# 2     GP   F   15       U       T  at_home   mother           1          2
# 3     GP   F   15       U       T   health   mother           1          3
# 4     GP   F   16       U       T    other   father           1          2
#
#    failures paid internet  health  absences  G1  G2  G3
# 0         0   no       no       3         4   0  11  11
# 1         0   no      yes       3         2   9  11  11
# 2         0   no      yes       3         6  12  13  12
# 3         0   no      yes       5         0  14  14  14
# 4         0   no       no       5         0  11  13  13

# %%
len(GP_port)
# Out:
# 423

# %%
MS_port=Dataframe_colegio1[Dataframe_colegio1['school']=='MS']
MS_port.head()
# Out:
#     school sex  age address Pstatus     Mjob guardian  traveltime  studytime  \
# 423     MS   F   16       U       T  at_home   father           2          1
# 424     MS   F   16       R       T    other   mother           2          2
# 425     MS   F   15       R       T  at_home   mother           1          1
# 426     MS   F   15       R       T  at_home   mother           2          1
# 427     MS   F   16       R       T  at_home   mother           2          2
#
#      failures paid internet  health  absences  G1  G2  G3
# 423         0   no      yes       5        11  10  11  11
# 424         0   no      yes       5         0  12  12  12
# 425         1   no       no       2         6  10  10  10
# 426         0   no      yes       5         4  10  10  11
# 427         0   no       no       5         0  16  17  17

# %%
len(MS_port)
# Out:
# 226

# %%
GP_port.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# Pstatus       0
# Mjob          0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# paid          0
# internet      0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
MS_port.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# Pstatus       0
# Mjob          0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# paid          0
# internet      0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
GP_port.value_counts('sex')
# Out:
# sex
# F    237
# M    186
# dtype: int64

# %%
GP_port.value_counts('sex').plot(kind="pie", autopct=("%1.1f%%"), explode = [0.1, 0])
plt.ylabel('SEX')
# Out:
# Text(0, 0.5, 'SEX')

# %%
MS_port.value_counts('sex')
# Out:
# sex
# F    146
# M     80
# dtype: int64

# %%
MS_port.value_counts('sex').plot(kind="pie", autopct=("%1.1f%%"), explode = [0.1, 0])
plt.ylabel('SEX')
# Out:
# Text(0, 0.5, 'SEX')

# %%
plt.figure(figsize=(10,5))
GP_port.value_counts('age').plot(kind="bar", color = 'black')
plt.title('Edad de los estudianes - Colegio GP')
# Out:
# Text(0.5, 1.0, 'Edad de los estudianes - Colegio GP')

# %%
plt.figure(figsize=(10,5))
MS_port.value_counts('age').plot(kind="bar", color = 'green')
plt.title('Edad de los estudianes - Colegio MS')
# Out:
# Text(0.5, 1.0, 'Edad de los estudianes - Colegio MS')

# %%
GP_port['age'].mean()
# Out:
# 16.666666666666668

# %%
MS_port['age'].mean()
# Out:
# 16.88938053097345

# %%
GP_port_promedio=GP_port[['G1', 'G2','G3']].mean()
print(GP_port_promedio)
# Out:
# G1    11.985816
# G2    12.144208
# G3    12.576832
# dtype: float64

# %%
MS_port_promedio=MS_port[['G1', 'G2','G3']].mean()
print(MS_port_promedio)
# Out:
# G1    10.300885
# G2    10.495575
# G3    10.650442
# dtype: float64

# %%
grupos_GP = ['G1','G2','G3']
#GP_math[['G1','G2','G3']].mean().plot(kind = "bar")
plt.barh(grupos_GP,GP_port_promedio, color='black')
plt.title('Grafica promedio notas - Colegio GP')
plt.ylabel('GRUPOS')
plt.xlabel('CALIFICACIONES')
# Out:
# Text(0.5, 0, 'CALIFICACIONES')

# %%
grupos_GP = ['G1','G2','G3']
#GP_math[['G1','G2','G3']].mean().plot(kind = "bar")
plt.barh(grupos_GP,MS_port_promedio, color='green')
plt.title('Grafica promedio notas - Colegio MS')
plt.ylabel('GRUPOS')
plt.xlabel('CALIFICACIONES')
# Out:
# Text(0.5, 0, 'CALIFICACIONES')

# %%
ClassMAX_GP = GP_port['absences'].max()
print(ClassMAX_GP)

ClassMAX_MS = MS_port['absences'].max()
print(ClassMAX_MS)
# Out:
# 32
# 12

# %%
AsistenciaMS = ((ClassMAX_MS - MS_port['absences'])/ClassMAX_MS) * 100

AsistenciaGP = ((ClassMAX_GP - GP_port['absences'])/ClassMAX_GP) * 100

AsistT_port = AsistenciaGP.add(AsistenciaMS, fill_value = 0)
G3T_port = GP_port['G3'].add(MS_port['G3'], fill_value = 0)

print(round(AsistT_port))

As2 = AsistT_port.lt(80) 
G3a = G3T_port.lt(10)
G3b = G3T_port.lt(15)
i = 0
appr = []
ext   = []

while(i < 649): 
    if(As2[i] == True):
        appr.append(0)
        ext.append(0)
        i+=1
    elif(As2[i] == False) & (G3a[i] == True):
        appr.append(0)
        ext.append(0)
        i+=1
    elif (As2[i] == False) & (G3a[i] == False) & (G3b[i] == True):
        appr.append(1)
        ext.append(1)
        i+=1
    elif (As2[i] == False) & (G3b[i] == False):
        appr.append(1)
        ext.append(0)
        i+=1 

Dataframe_colegio1 = Dataframe_colegio1.assign(APPROVED = appr, EXTRA = ext)
# Out:
# 0       88.0
# 1       94.0
# 2       81.0
# 3      100.0
# 4      100.0
#        ...
# 644     67.0
# 645     67.0
# 646     50.0
# 647     50.0
# 648     67.0
# Name: absences, Length: 649, dtype: float64

# %%
Dataframe_colegio1.head()
# Out:
#   school sex  age address Pstatus     Mjob guardian  traveltime  studytime  \
# 0     GP   F   18       U       A  at_home   mother           2          2
# 1     GP   F   17       U       T  at_home   father           1          2
# 2     GP   F   15       U       T  at_home   mother           1          2
# 3     GP   F   15       U       T   health   mother           1          3
# 4     GP   F   16       U       T    other   father           1          2
#
#    failures paid internet  health  absences  G1  G2  G3  APPROVED  EXTRA
# 0         0   no       no       3         4   0  11  11         1      1
# 1         0   no      yes       3         2   9  11  11         1      1
# 2         0   no      yes       3         6  12  13  12         1      1
# 3         0   no      yes       5         0  14  14  14         1      1
# 4         0   no       no       5         0  11  13  13         1      1

# %%
import datetime
Fech = datetime.datetime.now()

print(Fech)
# Out:
# 2022-10-16 21:37:12.585757

# %%
Dataframe_colegio1.to_csv('Resultado_Student_Port_2022-10-16.csv',sep=';')
Dataframe_colegio.to_csv('Resultado_Student_Math_2022-10-16.csv', sep=';')

# %%
Dataframe_Resultado = pd.concat([Dataframe_colegio, Dataframe_colegio1])

# %%
Dataframe_Resultado.to_csv('Rseultado_2022-10-16.csv', sep=';')
